# %%
# Guido van rossom developed Python programming language.

# %%
# Dynamically type Programming does python supports.

# %%
# Yes Python is case sensitive when dealing with identifiers.

# %%
#4 .py is the correct file extension.

# %%
#5 Yes Python is code interpreter. it can interpreted code line by line.
# which make python fast to devlopment 
# like you can just write a code and instantally saw the output and
# instantlly debug yourself.

# %%
#6 to Identifiers like def = it is used to define and create a new function
# and class function is used to create a new class. 
# are used to define in python language.

# %%
#7 # is that character used to give single line comments in python.

# %%
#8 Here are that functions which can help us to find the version of python 
# that we are currently working on.
import sys 
print(sys.version)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]

# %%
#9 Python supports the creation of anonymous functions at runtime, using a constuct called
# lambda function.
# like 
cube = lambda x : x**3
print(cube(5))
# Out:
# 125

# %%
# 10  Pip stands for Pip installs packeges. it is the manager of python library.
# it can install/update/manage libraries.

# %%
#11 Built in functions in python are over 60 and some of them are here - print() , range() , type() ,len() , str()
# , int() , float() ,sum() etc.

# %%
#12 there is not defined possible length of an identifier in Python , that 
# depends upon your system memory.

# %%
#13 Python is a dynamically type language is one of the key benifits of this 
# language means simple and easy syntax also it supports a large variety of library.
# also it can be used in artificial intelligence and data science field.

# %%
# 14. python me jab bhi ham kisi variable ko koi data assign karte hai to python use memory me save karke rakhta hai but jaise hi ham us data ke varible ko naya data assign kar dete hai to python ka garbage collector last wale data ko  remove kar deta hai.  
# जब पुराने डेटा से वेरिएबल हट जाता है और उसे इस्तेमाल करने वाला कोई नहीं बचता,
# तो गार्बेज कलेक्टर उसे तुरंत हटाकर मेमोरी खाली कर देता है।

# %%
# 15. Firstly Go to Python.org/download then select your Operating system 
# in my case it is windows the download it then at the time of installation 
# check the variable python.exe PATH then it will automatically save in your
# pc but if you want to manually set the PATH so open control pannel then
# search for Envirement Variable then go to system variable then click on 
# PATH then edit then new and finally paste here your python path which is 
# something like this -C:\Users\YourUsername\AppData\Local\Programs\Python\Python312
# at last again click on new then paste here python script path which is something
# like it - C:\Users\YourUsername\AppData\Local\Programs\Python\Python312\Scripts
# And finally Click on OK And Here we GO.

# %%
#16 Yes Indentation is vital for python.
# like we want to print Hello on python so we have to 
# type print("Hello") with proper indentation. if we do not do in this way or
# without proper indentation we will definatally found syntax error.
